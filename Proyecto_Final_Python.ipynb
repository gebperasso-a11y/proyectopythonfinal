# %% [markdown]
# # **UNIVERSIDAD DE LAS FUERZAS ARMADAS ESPE**
#
# #CURSO DE PYTHON
# # Proyecto de Evaluación Docente
#
# Integrantes:
# * Bonilla
# * Vivanco
# * Galárraga
# * Rosero Paul
# * Chamorro Diana
# * Oña Omar

# %% [markdown]
# #*Preparación* y Fundamentos
#
# **Planteamiento del problema**
#
# La Universidad de las Fuerzas Armadas ESPE realiza un proceso de evaluación docente con el fin de garantizar la calidad de la enseñanza. Este proceso considera cuatro parámetros fundamentales:
#
# 1. Autoevaluación: la valoración que el docente realiza sobre su propio desempeño.
#
# 2. Heteroevaluación: la calificación que asignan los estudiantes al docente.
#
# 3. Evaluación de pares: la opinión académica de los colegas.
#
# 4. Evaluación de directivos: la valoración otorgada por las autoridades de la institución.
#
# Cada uno de estos parámetros se califica en una escala de 0 a 5.
#
# El interés principal es analizar si existen diferencias significativas entre estos tipos de evaluación y cómo se relacionan entre sí. Esto permitirá identificar tendencias como:
#
# + ¿Los docentes tienden a calificarse más alto que los estudiantes?
#
# + ¿Coinciden las evaluaciones de pares y directivos con la percepción de los estudiantes?
#
# + ¿Cuál es el impacto de cada tipo de evaluación en el promedio final del docente?
#
# + Identificar desbalances en la percepción docente-estudiante.
#
# + Verificar coherencia entre pares y autoridades.
#
# + Evaluar la incidencia de cada parámetro en la nota global.

# %% [markdown]
# **Preguntas de investigación a responder con Python**
#
# ¿Cuál es el promedio de cada tipo de evaluación en los docentes?
#
# ¿Existen diferencias notorias entre autoevaluación y heteroevaluación?
#
# ¿Qué tan correlacionadas están las evaluaciones de pares y directivos con las demás?
#
# ¿Cómo cambia el promedio final de un docente si se modifican los pesos de cada evaluación?
#
# ¿Existen diferencias significativas en las calificaciones promedio de los docentes entre las distintas facultades o departamentos de la institución?

# %% [markdown]
# **Estructura inicial del programa**
#
# 1. Configuración del entorno
#
# * Se utilizará un cuaderno Jupyter/Google Colab.
#
# * Se instalarán y cargarán las librerías: pandas, numpy, sympy, matplotlib.
#
# 2. Implementación de scripts básicos
#
# * Variables y operadores: definir las calificaciones de ejemplo en escala de 0 a 5 y calcular promedios.
#
# * Condicionales: establecer categorías de desempeño (ej. excelente, bueno, aceptable).
#
# * Bucles: recorrer listas de calificaciones y calcular resultados por docente.
#
# * Funciones: crear una función que calcule el promedio de un docente a partir de sus cuatro evaluaciones.

# %%
#!pip install streamlit
#!pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import streamlit as st
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Ejemplo básico de código inicial:
#Variables en escala de 0 a 5
autoeval = 4.5
heteroeval = 4.2
pares = 4.3
directivos = 4.7

# Operadores: promedio simple
promedio = (autoeval + heteroeval + pares + directivos) / 4
st.write("Promedio inicial:", promedio)

# Condicionales: clasificación de desempeño
if promedio >= 4.5:
    print("Excelente desempeño docente")
elif promedio >= 4.0:
    print("Buen desempeño docente")
elif promedio >= 3.0:
    print("Desempeño aceptable")
else:
    print("Desempeño a mejorar")

# Función: cálculo de promedio general
def promedio_docente(valores):
    return sum(valores) / len(valores)

# Uso de la función
print("Promedio función:", promedio_docente([autoeval, heteroeval, pares, directivos]))

# Bucle: mostrar calificación de cada evaluación
for evaluacion in [("Autoevaluación", autoeval),
                   ("Heteroevaluación", heteroeval),
                   ("Pares", pares),
                   ("Directivos", directivos)]:
    print(evaluacion[0], ":", evaluacion[1])
# Out:
# 2025-09-17 09:37:16.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-17 09:37:16.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-17 09:37:16.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-17 09:37:16.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-17 09:37:16.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-17 09:37:16.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# Buen desempeño docente
# Promedio función: 4.425
# Autoevaluación : 4.5
# Heteroevaluación : 4.2
# Pares : 4.3
# Directivos : 4.7

# %%
print("Evaluación docente ESPE")

# Configuración de gráficos
plt.style.use("ggplot")

# URL con formato CSV
url = "https://docs.google.com/spreadsheets/d/18yMuI47bOAoVu-AcJ-nNjIj1iqsnKZGr/export?format=csv&gid=1030073867"

# Cargar datos
df = pd.read_csv(url)

# Mostrar primeras filas
print("Vista previa de los datos:")
print(df.head())
# Out:
# Evaluación docente ESPE
# Vista previa de los datos:
#                     Nombre      Departamento  Edad     Género       Sede  \
# 0  Carolina López Martínez  Ciencias Humanas    38   Femenino  Sangolquí
# 1    Jorge Rodríguez López   Administrativas    49  Masculino  Latacunga
# 2    Juan Rodríguez García  Ciencias Exactas    40   Femenino  Sangolquí
# 3    Daniela Jiménez López  Ciencias Humanas    50  Masculino  Latacunga
# 4   Carolina Pérez Jiménez  Ciencias Humanas    20  Masculino  Latacunga
#
#   Jornada laboral  Tipo de jornada Nombramiento o contrato  \
# 0          Diurna   Tiempo parcial            Nombramiento
# 1        Nocturna  Tiempo completo            Nombramiento
# 2        Nocturna  Tiempo completo                Contrato
# 3          Diurna   Tiempo parcial            Nombramiento
# 4        Nocturna     Medio tiempo                Contrato
#
#    Número de alumnos a cargo     Título profesional  Autoevaluación  \
# 0                        136  Ingeniería Industrial             5.0
# 1                         49    Doctorado en Física             4.8
# 2                         98    Doctorado en Física             4.8
# 3                         82    Doctorado en Física             4.5
# 4                        118    Doctorado en Letras             4.9
#
#    Co-evaluación  Hetero-evaluación  Evaluación directivos
# 0            4.1                3.8                    4.0
# 1            5.0                4.8                    4.4
# 2            3.6                4.5                    3.5
# 3            4.8                3.9                    4.5
# 4            4.4                4.7                    4.9

# %%
# Select the evaluation columns
eval_columns = ['Autoevaluación', 'Co-evaluación', 'Hetero-evaluación', 'Evaluación directivos']

# Create boxplots for each evaluation column
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[eval_columns])
plt.title('Boxplots de Columnas de Evaluación')
plt.ylabel('Puntuación')
plt.show()

# %%
# Create violin plots for each evaluation column
plt.figure(figsize=(10, 6))
sns.violinplot(data=df[eval_columns])
plt.title('Violin Plots de Columnas de Evaluación')
plt.ylabel('Puntuación')
plt.show()

# %%
# Create scatter plots for each pair of evaluation columns
sns.pairplot(df[eval_columns])
plt.suptitle('Scatter Plots de Columnas de Evaluación', y=1.02)
plt.show()

# %% [markdown]
# Calificaciones individuales

# %%
# Definir pesos
w_auto = 0.10
w_co = 0.30
w_hetero = 0.35
w_dir = 0.25

# Convertir columnas a numérico, reemplazando comas por puntos
df["Autoevaluación"] = df["Autoevaluación"].astype(float)
df["Co-evaluación"] = df["Co-evaluación"].astype(float)
df["Hetero-evaluación"] = df["Hetero-evaluación"].astype(float)
df["Evaluación directivos"] = df["Evaluación directivos"].astype(float)


# Calcular la calificación final
df["Calificación_Final"] = (
    df["Autoevaluación"] * w_auto +
    df["Co-evaluación"] * w_co +
    df["Hetero-evaluación"] * w_hetero +
    df["Evaluación directivos"] * w_dir
)
print("Vista previa de los datos:")
display(df.head())
# Out:
# Vista previa de los datos:
#                     Nombre      Departamento  Edad     Género       Sede  \
# 0  Carolina López Martínez  Ciencias Humanas    38   Femenino  Sangolquí
# 1    Jorge Rodríguez López   Administrativas    49  Masculino  Latacunga
# 2    Juan Rodríguez García  Ciencias Exactas    40   Femenino  Sangolquí
# 3    Daniela Jiménez López  Ciencias Humanas    50  Masculino  Latacunga
# 4   Carolina Pérez Jiménez  Ciencias Humanas    20  Masculino  Latacunga
#
#   Jornada laboral  Tipo de jornada Nombramiento o contrato  \
# 0          Diurna   Tiempo parcial            Nombramiento
# 1        Nocturna  Tiempo completo            Nombramiento
# 2        Nocturna  Tiempo completo                Contrato
# 3          Diurna   Tiempo parcial            Nombramiento
# 4        Nocturna     Medio tiempo                Contrato
#
#    Número de alumnos a cargo     Título profesional  Autoevaluación  \
# 0                        136  Ingeniería Industrial             5.0
# 1                         49    Doctorado en Física             4.8
# 2                         98    Doctorado en Física             4.8
# 3                         82    Doctorado en Física             4.5
# 4                        118    Doctorado en Letras             4.9
#
#    Co-evaluación  Hetero-evaluación  Evaluación directivos  Calificación_Final
# 0            4.1                3.8                    4.0                4.06
# 1            5.0                4.8                    4.4                4.76
# 2            3.6                4.5                    3.5                4.01
# 3            4.8                3.9                    4.5                4.38
# 4            4.4                4.7                    4.9                4.68

# %% [markdown]
# Boxplot por departamento

# %%
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.boxplot(x="Departamento", y="Calificación_Final", data=df, palette="Set2")

plt.title("Distribución de Calificación Final por Departamento", fontsize=14)
plt.xlabel("Departamento")
plt.ylabel("Calificación Final")
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Elizz\AppData\Local\Temp\ipykernel_30072\2372869338.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Departamento", y="Calificación_Final", data=df, palette="Set2")

# %% [markdown]
# Violin plot por sede

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(x="Sede", y="Calificación_Final", data=df, palette="pastel", inner="box")

plt.title("Distribución de Calificación Final por Sede", fontsize=14)
plt.xlabel("Sede")
plt.ylabel("Calificación Final")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Elizz\AppData\Local\Temp\ipykernel_30072\2594373570.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="Sede", y="Calificación_Final", data=df, palette="pastel", inner="box")

# %% [markdown]
# Etiquetar a los docentes según su desempeño

# %%
def clasificar_docente(nota):
    if nota >= 4.5:
        return "Excelente"
    elif nota >= 4.0:
        return "Bueno"
    elif nota >= 3.5:
        return "Regular"
    else:
        return "Bajo"

df["Desempeño"] = df["Calificación_Final"].apply(clasificar_docente)
display(df.head())
# Out:
#                     Nombre      Departamento  Edad     Género       Sede  \
# 0  Carolina López Martínez  Ciencias Humanas    38   Femenino  Sangolquí
# 1    Jorge Rodríguez López   Administrativas    49  Masculino  Latacunga
# 2    Juan Rodríguez García  Ciencias Exactas    40   Femenino  Sangolquí
# 3    Daniela Jiménez López  Ciencias Humanas    50  Masculino  Latacunga
# 4   Carolina Pérez Jiménez  Ciencias Humanas    20  Masculino  Latacunga
#
#   Jornada laboral  Tipo de jornada Nombramiento o contrato  \
# 0          Diurna   Tiempo parcial            Nombramiento
# 1        Nocturna  Tiempo completo            Nombramiento
# 2        Nocturna  Tiempo completo                Contrato
# 3          Diurna   Tiempo parcial            Nombramiento
# 4        Nocturna     Medio tiempo                Contrato
#
#    Número de alumnos a cargo     Título profesional  Autoevaluación  \
# 0                        136  Ingeniería Industrial             5.0
# 1                         49    Doctorado en Física             4.8
# 2                         98    Doctorado en Física             4.8
# 3                         82    Doctorado en Física             4.5
# 4                        118    Doctorado en Letras             4.9
#
#    Co-evaluación  Hetero-evaluación  Evaluación directivos  \
# 0            4.1                3.8                    4.0
# 1            5.0                4.8                    4.4
# 2            3.6                4.5                    3.5
# 3            4.8                3.9                    4.5
# 4            4.4                4.7                    4.9
#
#    Calificación_Final  Desempeño
# 0                4.06      Bueno
# 1                4.76  Excelente
# 2                4.01      Bueno
# 3                4.38      Bueno
# 4                4.68  Excelente

# %% [markdown]
# Búsqueda de docentes con más de 100 alumnos

# %%
print("\nDocentes con más de 100 alumnos a cargo:")
for i, row in df.iterrows():
    if row["Número de alumnos a cargo"] > 100:
        print(f"- {row['Nombre']} ({row['Número de alumnos a cargo']} alumnos)")
# Out:
# Docentes con más de 100 alumnos a cargo:
# - Carolina López Martínez (136 alumnos)
# - Carolina Pérez Jiménez (118 alumnos)
# - Jorge Martín Martín (143 alumnos)
# - Carlos Jiménez García (151 alumnos)
# - Patricia Martín López (102 alumnos)
# - Carlos Gómez Fernández (123 alumnos)
# - Esteban Fernández Jiménez (140 alumnos)
# - Daniela Gómez Martínez (123 alumnos)
# - Marta López Rodríguez (109 alumnos)
# - Carolina Gómez Martín (173 alumnos)
# - Andrea Fernández Pérez (159 alumnos)
# - Isabel Martín López (150 alumnos)
# - Ana Gómez Gómez (145 alumnos)
# - Ignacio Martín Sánchez (114 alumnos)
# - Laura Martínez Martín (168 alumnos)
# - Pedro Sánchez Martínez (132 alumnos)
# - Sofía Martín Martínez (101 alumnos)
# - Diego Pérez Jiménez (156 alumnos)
# - Natalia Martínez Martín (154 alumnos)
# - Pedro Gómez Sánchez (103 alumnos)
# - Marta Jiménez Rodríguez (135 alumnos)
# - Adriana Martín García (143 alumnos)
# - Ignacio García López (148 alumnos)
# - Jorge Martínez Martínez (165 alumnos)
# - Ana Gómez Pérez (144 alumnos)
# - Ana Martín Martín (114 alumnos)
# - Luis García García (142 alumnos)
# - María Pérez García (117 alumnos)
# - Javier López López (125 alumnos)
# - Natalia García Fernández (175 alumnos)
# - Pablo López Fernández (168 alumnos)
# - Sofía Gómez Fernández (148 alumnos)
# - Laura Martín García (149 alumnos)
# - Jorge Sánchez Gómez (167 alumnos)
# - María Jiménez Martín (130 alumnos)
# - Andrea Pérez Fernández (172 alumnos)
# - Jorge García Sánchez (154 alumnos)
# - Juan Martínez Martín (174 alumnos)
# - Patricia García Rodríguez (170 alumnos)
# - Andrea Martín Fernández (124 alumnos)
# - Gabriel Sánchez Gómez (165 alumnos)
# - Marta Martín Martín (142 alumnos)
# - Elena Jiménez Jiménez (124 alumnos)
# - Daniela Martínez Martín (135 alumnos)
# - Carolina Martín García (171 alumnos)
# - Ana Martín Fernández (140 alumnos)
# - Andrea Rodríguez Gómez (103 alumnos)
# - Marta Sánchez Sánchez (172 alumnos)
# - Jorge Martín Sánchez (156 alumnos)
# - Luis Rodríguez Martínez (106 alumnos)
# - Laura Jiménez Martín (172 alumnos)
# - Juan Sánchez Martín (111 alumnos)
# - Jorge López Rodríguez (150 alumnos)
# - Adriana Martín García (101 alumnos)
# - Fernando Martín López (161 alumnos)
# - Gabriel García Jiménez (130 alumnos)
# - Sofía Martín Jiménez (119 alumnos)
# - Laura Sánchez García (159 alumnos)
# - Natalia Fernández López (171 alumnos)
# - Jorge Martínez Martín (152 alumnos)
# - Rosa López Martín (109 alumnos)
# - Jorge Jiménez Fernández (107 alumnos)
# - Patricia García Martín (119 alumnos)
# - Fernando Martínez Pérez (140 alumnos)
# - Javier López García (162 alumnos)
# - Ignacio Martínez Rodríguez (154 alumnos)
# - Pablo Rodríguez Pérez (120 alumnos)
# - Marta Rodríguez Sánchez (168 alumnos)
# - Laura García Pérez (131 alumnos)
# - Patricia Gómez Fernández (112 alumnos)
# - Isabel Jiménez García (153 alumnos)
# - Ricardo Sánchez Martín (163 alumnos)
# - Pedro García García (143 alumnos)
# - Valeria Martínez Martín (109 alumnos)
# - Daniela Gómez López (135 alumnos)
# - Ana Sánchez Jiménez (164 alumnos)
# - Ignacio López Sánchez (119 alumnos)
# - Pedro Sánchez Gómez (116 alumnos)
# - Ignacio García Sánchez (130 alumnos)
# - Laura Martínez Martínez (154 alumnos)
# - Fernando Jiménez Martínez (130 alumnos)
# - Luis López Martínez (132 alumnos)
# - Marta Jiménez Pérez (137 alumnos)
# - Esteban Martín Sánchez (168 alumnos)
# - Gabriel Fernández Pérez (154 alumnos)
# - Fernando Pérez Fernández (108 alumnos)
# - Diego López Pérez (120 alumnos)
# - Diego García Pérez (149 alumnos)
# - Juan García Jiménez (101 alumnos)
# - Gabriel Jiménez Jiménez (129 alumnos)
# - Javier Fernández López (142 alumnos)
# - Valeria Gómez Gómez (131 alumnos)
# - Luis Jiménez Gómez (104 alumnos)
# - Javier Jiménez García (113 alumnos)
# - Daniela García Pérez (114 alumnos)
# - Fernando Fernández Pérez (120 alumnos)
# - Valeria Martín Gómez (148 alumnos)
# - Patricia García Martín (154 alumnos)
# - María Fernández Sánchez (102 alumnos)
# - Isabel Martín Gómez (125 alumnos)
# - Natalia Fernández Rodríguez (108 alumnos)
# - Elena Sánchez Sánchez (149 alumnos)
# - María Martín Gómez (127 alumnos)
# - Fernando Rodríguez Rodríguez (173 alumnos)
# - Diego Sánchez López (162 alumnos)
# - Alejandro Jiménez Fernández (134 alumnos)
# - Gabriel Fernández Sánchez (102 alumnos)
# - Isabel Gómez Pérez (125 alumnos)
# - Adriana López López (170 alumnos)
# - Pablo Jiménez Rodríguez (166 alumnos)
# - Adriana García Martín (152 alumnos)
# - Elena Martín Jiménez (174 alumnos)
# - Luis Martínez Fernández (151 alumnos)
# - María Pérez Martín (104 alumnos)
# - Rosa Sánchez Jiménez (124 alumnos)
# - Fernando Pérez Fernández (120 alumnos)
# - Esteban Jiménez López (172 alumnos)
# - Alejandro Sánchez Gómez (175 alumnos)
# - Elena Martín Gómez (133 alumnos)
# - Diego Rodríguez Jiménez (147 alumnos)
# - María García Jiménez (168 alumnos)
# - Ana Rodríguez Fernández (173 alumnos)
# - Daniela Pérez Rodríguez (128 alumnos)
# - Adriana García Sánchez (164 alumnos)
# - Ignacio Fernández Sánchez (168 alumnos)
# - Luis García Martínez (105 alumnos)
# - Daniela López Pérez (111 alumnos)
# - Valeria Jiménez Pérez (166 alumnos)
# - Laura Martínez Fernández (169 alumnos)
# - Ignacio Gómez Gómez (122 alumnos)
# - Diego Sánchez Rodríguez (133 alumnos)
# - Valeria Sánchez López (140 alumnos)
# - María Jiménez Fernández (111 alumnos)
# - Diego Fernández García (128 alumnos)
# - Luis López Martínez (147 alumnos)
# - Gabriel Sánchez Martínez (103 alumnos)
# - Isabel Gómez Rodríguez (121 alumnos)
# - Javier Jiménez Fernández (123 alumnos)
# - Alejandro Jiménez Fernández (107 alumnos)
# - Ignacio López Fernández (134 alumnos)
# - Alejandro Martín López (165 alumnos)
# - Patricia Rodríguez Pérez (157 alumnos)
# - Sofía Sánchez García (119 alumnos)
# - Valeria Rodríguez Gómez (113 alumnos)
# - Manuel Martín Martín (153 alumnos)
# - Ricardo Sánchez Jiménez (111 alumnos)
# - Valeria Fernández García (120 alumnos)
# - Valeria Rodríguez García (112 alumnos)
# - Jorge Gómez Sánchez (123 alumnos)
# - Adriana Rodríguez Martínez (151 alumnos)
# - Sofía Sánchez Jiménez (135 alumnos)
# - Pablo Gómez Gómez (153 alumnos)
# - Pablo Sánchez López (105 alumnos)
# - Elena Gómez Jiménez (108 alumnos)
# - Manuel Gómez Martín (136 alumnos)
# - Luis Fernández López (155 alumnos)
# - Carlos Jiménez García (132 alumnos)
# - Javier Pérez Martín (133 alumnos)
# - Natalia Pérez Jiménez (126 alumnos)
# - Ana López Rodríguez (165 alumnos)
# - Laura Gómez Jiménez (165 alumnos)
# - Carolina Martínez López (110 alumnos)
# - Elena Gómez Gómez (135 alumnos)
# - María Gómez Pérez (133 alumnos)
# - Elena Gómez Gómez (110 alumnos)
# - Alejandro López Martínez (114 alumnos)
# - Daniela Sánchez López (139 alumnos)
# - Patricia Pérez Sánchez (175 alumnos)
# - Laura Jiménez Gómez (101 alumnos)
# - Isabel Gómez Fernández (161 alumnos)
# - Javier Jiménez Pérez (122 alumnos)
# - Elena López Jiménez (158 alumnos)
# - Jorge Martínez Rodríguez (140 alumnos)
# - Diego Martín Sánchez (137 alumnos)
# - Luis Rodríguez Pérez (123 alumnos)
# - Fernando Martínez Sánchez (142 alumnos)
# - Gabriel Martín Jiménez (144 alumnos)
# - Ignacio Sánchez Sánchez (127 alumnos)
# - Ana Sánchez Sánchez (164 alumnos)
# - Elena Pérez Gómez (126 alumnos)
# - Adriana Martín Sánchez (134 alumnos)
# - Isabel Fernández Jiménez (164 alumnos)
# - Adriana López Martín (141 alumnos)
# - Sofía Jiménez Rodríguez (112 alumnos)
# - Fernando López López (145 alumnos)
# - Sofía García García (113 alumnos)
# - Javier García Gómez (149 alumnos)
# - Daniela Gómez Rodríguez (142 alumnos)
# - Elena Jiménez Pérez (140 alumnos)
# - Carlos García Martín (142 alumnos)
# - Adriana Martínez Pérez (134 alumnos)
# - Fernando Gómez Fernández (146 alumnos)
# - Marta Martínez Pérez (116 alumnos)
# - Javier García Fernández (135 alumnos)
# - Marta Fernández Pérez (121 alumnos)
# - Daniela Martínez Martínez (102 alumnos)
# - Laura Martínez Fernández (116 alumnos)
# - Fernando Fernández Fernández (117 alumnos)
# - Pablo Gómez García (103 alumnos)
# - Esteban Fernández Rodríguez (134 alumnos)
# - Elena Fernández Pérez (126 alumnos)
# - Rosa García Sánchez (130 alumnos)
# - Carolina López Sánchez (111 alumnos)
# - Fernando Martín López (105 alumnos)
# - Rosa Fernández Gómez (162 alumnos)
# - Patricia García Jiménez (159 alumnos)
# - Natalia Gómez García (149 alumnos)
# - Isabel Martín Rodríguez (169 alumnos)
# - Luis Jiménez Gómez (156 alumnos)
# - Esteban Jiménez Rodríguez (147 alumnos)
# - Valeria Martín Rodríguez (102 alumnos)
# - Adriana Fernández Jiménez (145 alumnos)
# - Esteban Martín López (170 alumnos)
# - Esteban García López (123 alumnos)
# - Elena Pérez Fernández (156 alumnos)
# - Daniela Martínez Pérez (132 alumnos)
# - Elena Fernández Pérez (114 alumnos)
# - Rosa Jiménez Martín (151 alumnos)
# - Pedro Jiménez Martínez (114 alumnos)
# - Patricia Rodríguez Pérez (111 alumnos)
# - Carolina Martín García (114 alumnos)
# - Manuel Sánchez Gómez (158 alumnos)
# - Marta Martínez García (110 alumnos)
# - Diego Gómez García (125 alumnos)
# - Fernando Sánchez Jiménez (170 alumnos)
# - Diego García Sánchez (119 alumnos)
# - Fernando Sánchez Fernández (125 alumnos)
# - Carlos Sánchez Jiménez (142 alumnos)
# - Fernando Pérez Martín (118 alumnos)
# - Ana Jiménez Martínez (161 alumnos)
# - Daniela López Sánchez (173 alumnos)
# - Isabel Pérez Pérez (141 alumnos)
# - Carolina López Fernández (141 alumnos)
# - Pablo Rodríguez García (159 alumnos)
# - Luis López Sánchez (132 alumnos)
# - Daniela Martínez López (119 alumnos)
# - Elena López Jiménez (146 alumnos)
# - Javier Martín Pérez (147 alumnos)
# - Diego Rodríguez Gómez (137 alumnos)
# - Pedro Gómez Fernández (122 alumnos)
# - Pedro Jiménez Martín (117 alumnos)
# - Laura Rodríguez Rodríguez (151 alumnos)
# - Carlos Martínez Pérez (158 alumnos)
# - Carlos Sánchez Gómez (109 alumnos)
# - Laura Jiménez Rodríguez (168 alumnos)
# - Javier Gómez Jiménez (119 alumnos)
# - Ricardo Martínez Jiménez (166 alumnos)
# - Carolina Sánchez Gómez (143 alumnos)
# - Pablo García López (174 alumnos)
# - Valeria Pérez Jiménez (146 alumnos)

# %% [markdown]
# Función que calcule promedio de calificación por departamento

# %%
def promedio_departamento(depto):
    subset = df[df["Departamento"] == depto]
    return subset["Calificación_Final"].mean()

print("\nPromedio de calificación por departamento:")
for depto in df["Departamento"].unique():
    print(f"{depto}: {promedio_departamento(depto):.2f}")
# Out:
# Promedio de calificación por departamento:
# Ciencias Humanas: 4.27
# Administrativas: 4.33
# Ciencias Exactas: 4.33
# Finanzas: 4.27

# %% [markdown]
# # Conclusiones
#
# El sistema de evaluación docente de la Universidad de las Fuerzas Armadas ESPE se sustenta en un enfoque integral que combina distintas perspectivas como la autoevaluación, heteroevaluación, pares y directivos. Esta diversidad de fuentes permite obtener resultados más objetivos, reduciendo el sesgo que podría generarse si se considerara únicamente una dimensión.
#
# La autoevaluación evidencia el nivel de autocrítica y conciencia profesional del docente respecto a sus propias prácticas. La heteroevaluación, realizada por los estudiantes, refleja la percepción directa del impacto pedagógico en el aula. La evaluación de pares resalta la calidad metodológica y académica desde la experiencia compartida, mientras que la de directivos ofrece una visión estratégica del desempeño y alineación institucional.
#
# Aunque la calificación se establece sobre 5, los resultados pueden estar influenciados por factores externos como la subjetividad de los estudiantes o las condiciones institucionales. Esto evidencia la necesidad de acompañar la evaluación con procesos de retroalimentación continua, planes de capacitación docente y mecanismos de seguimiento.
#
# Los resultados de la evaluación no deben interpretarse únicamente como un indicador numérico, sino como una herramienta de mejora continua. Al analizar conjuntamente los cuatro parámetros, se obtiene una radiografía más completa del quehacer docente, lo que contribuye al fortalecimiento de la calidad académica de la institución.
#
# La implementación de análisis automatizados en Python como se realizó en este trabaj abre la posibilidad de procesar grandes volúmenes de datos, generar reportes dinámicos y detectar patrones de desempeño. Esto favorece la toma de decisiones basadas en evidencias y consolida la transparencia en los procesos de evaluación docente
